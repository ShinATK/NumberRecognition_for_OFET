# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
accus1 = np.loadtxt('./output/lwl_1 全数字 学习率1.txt')
accus2 = np.loadtxt('./output/lwl_2 全数字 学习率1.txt')

# %%
plt.plot(accus1, label='accus1')
plt.plot(accus2, label='accus2')
plt.ylim(0, 100)
plt.legend()
plt.show()

# %%
plt.plot(abs(accus1-accus2)/100)

plt.show()
